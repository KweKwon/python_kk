# %% [markdown]
# #연산자의 종류와 활용
# ## 1) 연산자의 종류
# *

# %% [markdown]
# # 연산자의 종류와 활용
# ## 1) 연산자의 종류
# * 산술연산자: +, - , *, /, %(나머지), **(제곱), //(몫)

# %% [markdown]
# * 더하기+

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# * 뺴기-

# %%
print(3-2)
# Out:
# 1

# %% [markdown]
# * 곱하기*

# %%
print(3*3)
# Out:
# 9

# %% [markdown]
# * 나누기/ (나누기를하면 실수로 바뀐다)

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %% [markdown]
# * 나머지 %

# %%
print(5 % 3)
# Out:
# 2

# %% [markdown]
# * 제곱**

# %%
print(3**2)
# Out:
# 9

# %% [markdown]
# * 몫//

# %%
print(9//2)
# Out:
# 4

# %% [markdown]
# * 괄호 사용법: ()안쪽이 연산에서 우선 순위를 갖는다.

# %%
(3+4)*2
# Out:
# 14

# %% [markdown]
# 1. 3*2+5를 계산하시

# %%
3*2+5
# Out:
# 11

# %%
20210906//23
# Out:
# 878735

# %%
20210906%23
# Out:
# 1

# %%
6*8
# Out:
# 48

# %%
(6*8+5)/3
# Out:
# 17.666666666666668

# %%
(((3**4)-100)**3)//5+1
# Out:
# -1371

# %% [markdown]
# ## 할당 연산자: *, +=, -=, *=, /=, %=

# %%
a = 3

# %%
a = a + 3
a
# Out:
# 6

# %%
b = 0

# %%
b += 3
b
# Out:
# 3

# %%
b -= 1
b
# Out:
# 2

# %%
b *= 3
b
# Out:
# 6

# %%
b /= 4
b
# Out:
# 1.5

# %%
b %= 2
b
# Out:
# 1.5

# %% [markdown]
# ## 비교연산자: ==,!=,>,<,>=,<=
# * 왼쪽을 기준으로 비교

# %%
a = 3
b = 3.0
c = 5
d = 'Python'
e = 'python'
f = True
g = False

# %% [markdown]
# * == 같으면 True ,다르면 False

# %%
a == b
# Out:
# True

# %%
a == c
# Out:
# False

# %%
d == e
# Out:
# False

# %% [markdown]
# * != 다르면 True, 같으면 False

# %%
a != c
# Out:
# True

# %%
a != b
# Out:
# False

# %% [markdown]
# <li> >왼쪽을 기준으로 왼쪽 값이 오른쪽 보다 큰지 (초과) </li>

# %%
a > c
# Out:
# False

# %%
c > b
# Out:
# True

# %% [markdown]
# <li>  왼쪽을 기준으로 오른쪽보다 작은지(미만)</li>

# %%
c < a
# Out:
# False

# %%
a < c
# Out:
# True

# %% [markdown]
# <li> >= 왼쪽값이 오른쪽 값의 이상인지</li>

# %%
a >= b
# Out:
# True

# %% [markdown]
# <li> <=왼쪽값이 오른값의 이하인지

# %%
a <= b
# Out:
# True

# %%
c <= b
# Out:
# False

# %% [markdown]
# * 식별 연산자: is, is not - 객체(object)가 같은지 비교

# %%
print(a)
print(b)
print(c)
# Out:
# 3
# 3.0
# 5

# %%
a == b
# Out:
# True

# %%
a == c
# Out:
# False

# %%
a is c
# Out:
# False

# %%
type(a)
type(c)
# Out:
# int

# %%
print(type(a) is type(c))
# Out:
# True

# %%
print(id(a))
print(id(b))
# Out:
# 138205238116656
# 138203969272496

# %% [markdown]
# * 논리연산자: and, or, not

# %% [markdown]
# * and 비교하는 두 값 모두가 참이어야 참

# %%
True and True
# Out:
# True

# %%
a == b and b == a
# Out:
# True

# %%
True and False
# Out:
# False

# %%
a == b and  a == c
# Out:
# False

# %%
False and False
# Out:
# False

# %%
a >b and a == c
# Out:
# False

# %% [markdown]
# * or 두 값 중 하나라도 참이면 모두 참, 두 값 모두가 거짓이면 거짓

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
a == b or a > b
# Out:
# True

# %% [markdown]
# * not 값을 반대로 뒤집음, True = False, False = True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# * and, or, not 논리 연산자가 식 하나에 들어 있을 때
# * not, and, or 순으로 판단

# %%
not True and False or not False
# Out:
# True

# %% [markdown]
# * 멤버 연산자: in, not in
#   * in 객체(변수) 내에 해당 값이 있으면 True,없으면False

# %%
mem = [1,2,3,4,5]

# %%
1 in mem
# Out:
# True

# %%
6 in mem
# Out:
# False

# %%
6 not in mem
# Out:
# True

# %%
1 not in mem
# Out:
# False

# %% [markdown]
# 1. JAVA,Python,SQL 점수가 있을 때 한 과목이라도 60점 미만이면 불합격이라고 정했습니다. 다음 소스 코드를 완선하여 합격이면 True,불합격이면 False가 출력되게 만드시오.

# %%
Java= 92
Python = 47
sql = 85

# %% [markdown]
# * 비교연산자,논리연산자

# %%
print(Java >= 60 and Python >= 60 and sql >= 60)
# Out:
# False
