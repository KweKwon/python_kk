# %% [markdown]
# # pandas
#
# ## 1.판다스의 특징
# * Numpy를 내부적으로 활용(Numpy의 특징을 그대로 가짐)
# * 데이터 분석에 특화된 데이터 구조 제공
# * 다향한 데이터 분석 임무 제공
# * 데이터베이스에 쉽게 연결 가능

# %% [markdown]
# # 2. 판다스 설치
# * conda install pandas
# * pip install pandas

# %% [markdown]
# ## 3. 판다스 불러오기
# * import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# ## 4. 판다스에서 다루는 데이터 타입
# * Series 시리즈: 파이썬 리스트와 비슷, 여러 자료형의 데이터가 들어가고 순서가 있다.
# * DataFrame 데이터프레임: 2차원의 엑셀 시트와 같은 데이터 타입, 시리즈의 모임

# %% [markdown]
# ## 5. 데이터 프레임 만들기
# * pd.DataFrame({key : value, key : value})

# %%
df = pd.DataFrame({
    "이름" : ["홍길동", "파김치", "김가네"],
    "age" : [22, 35, 58],
    "성별" : ['male', "male", "female"]
})

# %%
df
# Out:
#     이름  age      성별
# 0  홍길동   22    male
# 1  파김치   35    male
# 2  김가네   58  female

# %%
df['이름'][:2]
# Out:
# 0    홍길동
# 1    파김치
# Name: 이름, dtype: object

# %%
df['age']
# Out:
# 0    22
# 1    35
# 2    58
# Name: age, dtype: int64

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(df['이름']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.ndim
# Out:
# 2

# %%
df['이름'].ndim
# Out:
# 1

# %% [markdown]
# ## 6. 시리즈 만들기
# * pd.Series(리스트/튜플 자료, name="컬럼명")

# %%
ages = pd.Series([22,35,58], name='AGE')
ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: AGE, dtype: int64

# %%
ages.max()
# Out:
# 58

# %%
ages.min()
# Out:
# 22

# %%
ages.mean()
# Out:
# 38.333333333333336

# %%
ages.median()
# Out:
# 35.0

# %%
ages.describe()
# Out:
# count     3.000000
# mean     38.333333
# std      18.230012
# min      22.000000
# 25%      28.500000
# 50%      35.000000
# 75%      46.500000
# max      58.000000
# Name: AGE, dtype: float64

# %% [markdown]
# # 판다스에서 자료 불러오기 저장하기
# * pd.read_확장자('경로',encoding='코드셋)
# * pd.read_csv: csv 파일 읽어올 때
# * pd.read_excel: excel파일 읽어올 때
# * pd.read_json: json 파일 읽어올 때
# * pd.read_sql: sql파일 읽어올 때
# * pd.read_html: html파일에서 표 읽어올 때

# %%
data = pd.read_csv("https://raw.githubusercontent.com/haram4th/ADsP/main/01%EB%B3%B4%EC%8A%A4%ED%84%B4%EC%A7%91%EA%B0%92%EB%8D%B0%EC%9D%B4%ED%84%B0.csv")

# %%
data
# Out:
#          범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 0    0.00632          18.0       2.31      0     0.538    6.575         65.2
# 1    0.02731           0.0       7.07      0     0.469    6.421         78.9
# 2    0.02729           0.0       7.07      0     0.469    7.185         61.1
# 3    0.03237           0.0       2.18      0     0.458    6.998         45.8
# 4    0.06905           0.0       2.18      0     0.458    7.147         54.2
# ..       ...           ...        ...    ...       ...      ...          ...
# 501  0.06263           0.0      11.93      0     0.573    6.593         69.1
# 502  0.04527           0.0      11.93      0     0.573    6.120         76.7
# 503  0.06076           0.0      11.93      0     0.573    6.976         91.0
# 504  0.10959           0.0      11.93      0     0.573    6.794         89.3
# 505  0.04741           0.0      11.93      0     0.573    6.030         80.8
#
# ...

# %%
pwd
# Out:
# 'c:\\bigdata'

# %%
data2 = pd.read_excel("./data/titanic.xlsx", engine="openpyxl")

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs
from tqdm import tqdm
import time
import lxml

# %%
# 웹드라이버를 버전에 맞게 자동으로 다운 받고 옵션을 추가해 줌
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
# driver = webdriver.Chrome(ChromeDriverManager().install())
driver.set_window_size(1920,1080)   # 웹브라우저 해상도 조절

driver.get("https://www.starbucks.co.kr/menu/drink_list.do")  # 크롤링 할 웹사이트 주소

# %%
link = "#container > div.content > div.product_result_wrap.product_result_wrap01 > div > dl > dt.dt2 > a"
search_box = driver.find_element(By.CSS_SELECTOR, link).click()
page_html = driver.page_source          # 페이지 끝에서 40개의 책이 로딩된 결과를 저장
soup = bs(page_html, "html.parser")

# %%
print(type(page_html))
# Out:
# <class 'str'>

# %%
data3 = pd.read_html(page_html)

# %%
data3[2]
# Out:
#                        메뉴  칼로리(Kcal)  당류(g)  단백질(g)  나트륨(mg)  포화지방(g)  카페인(mg)
# 0              마롱 헤이즐넛 라떼        280     35       8    130.0      5.0       85
# 1          아이스 마롱 헤이즐넛 라떼        190     28       4     65.0      2.4       85
# 2             블랙 글레이즈드 라떼        385     37      11    220.0     14.0       75
# 3         아이스 블랙 글레이즈드 라떼        305     31       7    160.0     11.0       75
# 4              에스프레소 콘 파나         30      1       0      0.0      1.5       75
# 5              에스프레소 마키아또         10      0       1      0.0      0.0       75
# 6            아이스 카페 아메리카노         10      0       1      5.0      0.0      150
# 7                카페 아메리카노         10      0       1      5.0      0.0      150
# 8            아이스 카라멜 마키아또        190     22       6    110.0      4.6       75
# 9                카라멜 마키아또        200     22       8    130.0      5.0       75
# 10               아이스 카푸치노        110      9       6     90.0      3.5       75
# ...

# %% [markdown]
# # 데이터 프레임을 파일로 저장
# * to_확장자("경로")

# %%
data.to_csv("./data/titanic.csv", index=False, encoding="utf-8")

# %%
test = pd.read_csv("./data/titanic.csv")

# %%
test
# Out:
#          범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 0    0.00632          18.0       2.31      0     0.538    6.575         65.2
# 1    0.02731           0.0       7.07      0     0.469    6.421         78.9
# 2    0.02729           0.0       7.07      0     0.469    7.185         61.1
# 3    0.03237           0.0       2.18      0     0.458    6.998         45.8
# 4    0.06905           0.0       2.18      0     0.458    7.147         54.2
# ..       ...           ...        ...    ...       ...      ...          ...
# 501  0.06263           0.0      11.93      0     0.573    6.593         69.1
# 502  0.04527           0.0      11.93      0     0.573    6.120         76.7
# 503  0.06076           0.0      11.93      0     0.573    6.976         91.0
# 504  0.10959           0.0      11.93      0     0.573    6.794         89.3
# 505  0.04741           0.0      11.93      0     0.573    6.030         80.8
#
# ...

# %%
test.to_csv("./data/titanic2.csv")

# %%
test2 = pd.read_csv("./data/titanic2.csv")
test2
# Out:
#      Unnamed: 0      범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  \
# 0             0  0.00632          18.0       2.31      0     0.538    6.575
# 1             1  0.02731           0.0       7.07      0     0.469    6.421
# 2             2  0.02729           0.0       7.07      0     0.469    7.185
# 3             3  0.03237           0.0       2.18      0     0.458    6.998
# 4             4  0.06905           0.0       2.18      0     0.458    7.147
# ..          ...      ...           ...        ...    ...       ...      ...
# 501         501  0.06263           0.0      11.93      0     0.573    6.593
# 502         502  0.04527           0.0      11.93      0     0.573    6.120
# 503         503  0.06076           0.0      11.93      0     0.573    6.976
# 504         504  0.10959           0.0      11.93      0     0.573    6.794
# 505         505  0.04741           0.0      11.93      0     0.573    6.030
#
# ...

# %%
data.to_excel("./data/boston.xlsx", index=False)

# %% [markdown]
# # 데이터 프레임 조회하기

# %%
# head() 데이터 프레임의 윗 5개 자료 조회
data.head()
# Out:
#        범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 0  0.00632          18.0       2.31      0     0.538    6.575         65.2
# 1  0.02731           0.0       7.07      0     0.469    6.421         78.9
# 2  0.02729           0.0       7.07      0     0.469    7.185         61.1
# 3  0.03237           0.0       2.18      0     0.458    6.998         45.8
# 4  0.06905           0.0       2.18      0     0.458    7.147         54.2
#
#    직업센터접근성  도로접근성   재산세율  학생/교사비율    흑인비율  하위계층비율  주택가격
# 0   4.0900      1  296.0     15.3  396.90    4.98  24.0
# 1   4.9671      2  242.0     17.8  396.90    9.14  21.6
# 2   4.9671      2  242.0     17.8  392.83    4.03  34.7
# 3   6.0622      3  222.0     18.7  394.63    2.94  33.4
# 4   6.0622      3  222.0     18.7  396.90    5.33  36.2

# %%
data.head(2)
# Out:
#        범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 0  0.00632          18.0       2.31      0     0.538    6.575         65.2
# 1  0.02731           0.0       7.07      0     0.469    6.421         78.9
#
#    직업센터접근성  도로접근성   재산세율  학생/교사비율   흑인비율  하위계층비율  주택가격
# 0   4.0900      1  296.0     15.3  396.9    4.98  24.0
# 1   4.9671      2  242.0     17.8  396.9    9.14  21.6

# %%
# tail() 데이터 프레임의 끝 자료 조회
data.tail()
# Out:
#          범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 501  0.06263           0.0      11.93      0     0.573    6.593         69.1
# 502  0.04527           0.0      11.93      0     0.573    6.120         76.7
# 503  0.06076           0.0      11.93      0     0.573    6.976         91.0
# 504  0.10959           0.0      11.93      0     0.573    6.794         89.3
# 505  0.04741           0.0      11.93      0     0.573    6.030         80.8
#
#      직업센터접근성  도로접근성   재산세율  학생/교사비율    흑인비율  하위계층비율  주택가격
# 501   2.4786      1  273.0     21.0  391.99    9.67  22.4
# 502   2.2875      1  273.0     21.0  396.90    9.08  20.6
# 503   2.1675      1  273.0     21.0  396.90    5.64  23.9
# 504   2.3889      1  273.0     21.0  393.45    6.48  22.0
# 505   2.5050      1  273.0     21.0  396.90    7.88  11.9

# %%
data.tail(2)
# Out:
#          범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 504  0.10959           0.0      11.93      0     0.573    6.794         89.3
# 505  0.04741           0.0      11.93      0     0.573    6.030         80.8
#
#      직업센터접근성  도로접근성   재산세율  학생/교사비율    흑인비율  하위계층비율  주택가격
# 504   2.3889      1  273.0     21.0  393.45    6.48  22.0
# 505   2.5050      1  273.0     21.0  396.90    7.88  11.9

# %%
# 데이터 프레임의 데이터 타입을 보고 싶을 때
data.dtypes
# Out:
# 범죄율             float64
# 25,000평방피트초과    float64
# 비소매상업지역비율       float64
# 찰스강경계             int64
# 농축 일산화질소        float64
# 가구당평균방수         float64
# 1940년이전건축비율     float64
# 직업센터접근성         float64
# 도로접근성             int64
# 재산세율            float64
# 학생/교사비율         float64
# 흑인비율            float64
# 하위계층비율          float64
# 주택가격            float64
# dtype: object

# %%
# 데이터 프레임의 컬럼, 널 갯수, 데이터 타입을 한 번에
# .info()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   범죄율           506 non-null    float64
#  1   25,000평방피트초과  506 non-null    float64
#  2   비소매상업지역비율     506 non-null    float64
#  3   찰스강경계         506 non-null    int64
#  4   농축 일산화질소      506 non-null    float64
#  5   가구당평균방수       506 non-null    float64
#  6   1940년이전건축비율   506 non-null    float64
#  7   직업센터접근성       506 non-null    float64
#  8   도로접근성         506 non-null    int64
#  9   재산세율          506 non-null    float64
#  10  학생/교사비율       506 non-null    float64
#  11  흑인비율          506 non-null    float64
#  12  하위계층비율        506 non-null    float64
#  13  주택가격          506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
# 컬럼 일부만 조회하기
# 데이터프레임명[["컬럼명1", "컬럼명2", ...]] 
# => 2개 이상의 컬럼을 조회시 중첩 리스트를 사용해야 함
data[['흑인비율', '주택가격', '범죄율']]
# Out:
#        흑인비율  주택가격      범죄율
# 0    396.90  24.0  0.00632
# 1    396.90  21.6  0.02731
# 2    392.83  34.7  0.02729
# 3    394.63  33.4  0.03237
# 4    396.90  36.2  0.06905
# ..      ...   ...      ...
# 501  391.99  22.4  0.06263
# 502  396.90  20.6  0.04527
# 503  396.90  23.9  0.06076
# 504  393.45  22.0  0.10959
# 505  396.90  11.9  0.04741
#
# [506 rows x 3 columns]

# %% [markdown]
# ## 데이터 프레임에서 조건에 맞는 행만 가져오기
# ## 데이터프레임[데이터프레임['컬럼명'] 조건식] => 조건식이 참인 것만 가져옴
# * <b> >, < >=, <=, ==, !=, &(and), |(or)

# %%
data['범죄율'] < 0.05
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 501    False
# 502     True
# 503    False
# 504    False
# 505     True
# Name: 범죄율, Length: 506, dtype: bool

# %%
# 조건이 1개인 경우
data[data['범죄율'] < 0.05]
# Out:
#          범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 0    0.00632          18.0       2.31      0     0.538    6.575         65.2
# 1    0.02731           0.0       7.07      0     0.469    6.421         78.9
# 2    0.02729           0.0       7.07      0     0.469    7.185         61.1
# 3    0.03237           0.0       2.18      0     0.458    6.998         45.8
# 5    0.02985           0.0       2.18      0     0.458    6.430         58.7
# ..       ...           ...        ...    ...       ...      ...          ...
# 349  0.02899          40.0       1.25      0     0.429    6.939         34.5
# 353  0.01709          90.0       2.02      0     0.410    6.728         36.1
# 354  0.04301          80.0       1.91      0     0.413    5.663         21.9
# 502  0.04527           0.0      11.93      0     0.573    6.120         76.7
# 505  0.04741           0.0      11.93      0     0.573    6.030         80.8
#
# ...

# %%
# 조건이 2개인 경우
# 0.05 < 범죄율 < 0.1
data[(data['범죄율'] > 0.05) & (data['범죄율'] < 0.1)]
# Out:
#          범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 4    0.06905           0.0       2.18      0     0.458    7.147         54.2
# 6    0.08829          12.5       7.87      0     0.524    6.012         66.6
# 12   0.09378          12.5       7.87      0     0.524    5.889         39.0
# 35   0.06417           0.0       5.96      0     0.499    5.933         68.2
# 36   0.09744           0.0       5.96      0     0.499    5.841         61.4
# ..       ...           ...        ...    ...       ...      ...          ...
# 350  0.06211          40.0       1.25      0     0.429    6.490         44.4
# 351  0.07950          60.0       1.69      0     0.411    6.579         35.9
# 352  0.07244          60.0       1.69      0     0.411    5.884         18.5
# 501  0.06263           0.0      11.93      0     0.573    6.593         69.1
# 503  0.06076           0.0      11.93      0     0.573    6.976         91.0
#
# ...

# %%
# 조건이 3개인 경우
# 범죄율 0.05 미만, 가구당 평균 방 수 >= 4, 하위계층비율 3 이하 인 집
data[(data['범죄율'] < 0.05) & (data['가구당평균방수'] >= 4) & (data['하위계층비율'] <= 3)]
# Out:
#          범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 3    0.03237           0.0       2.18      0    0.4580    6.998         45.8
# 40   0.03359          75.0       2.95      0    0.4280    7.024         15.8
# 195  0.01381          80.0       0.46      0    0.4220    7.875         32.0
# 204  0.02009          95.0       2.68      0    0.4161    8.034         31.9
#
#      직업센터접근성  도로접근성   재산세율  학생/교사비율    흑인비율  하위계층비율  주택가격
# 3     6.0622      3  222.0     18.7  394.63    2.94  33.4
# 40    5.4011      3  252.0     18.3  395.62    1.98  34.9
# 195   5.6484      4  255.0     14.4  394.23    2.97  50.0
# 204   5.1180      4  224.0     14.7  390.55    2.88  50.0

# %%
data.loc[(data['범죄율'] < 0.05) & (data['가구당평균방수'] >= 4) & (data['하위계층비율'] <= 3), ['가구당평균방수', '주택가격']]
# Out:
#      가구당평균방수  주택가격
# 3      6.998  33.4
# 40     7.024  34.9
# 195    7.875  50.0
# 204    8.034  50.0

# %%
data.loc[(data['범죄율'] < 0.05) & (data['가구당평균방수'] >= 4) & (data['하위계층비율'] <= 3)]
# Out:
#          범죄율  25,000평방피트초과  비소매상업지역비율  찰스강경계  농축 일산화질소  가구당평균방수  1940년이전건축비율  \
# 3    0.03237           0.0       2.18      0    0.4580    6.998         45.8
# 40   0.03359          75.0       2.95      0    0.4280    7.024         15.8
# 195  0.01381          80.0       0.46      0    0.4220    7.875         32.0
# 204  0.02009          95.0       2.68      0    0.4161    8.034         31.9
#
#      직업센터접근성  도로접근성   재산세율  학생/교사비율    흑인비율  하위계층비율  주택가격
# 3     6.0622      3  222.0     18.7  394.63    2.94  33.4
# 40    5.4011      3  252.0     18.3  395.62    1.98  34.9
# 195   5.6484      4  255.0     14.4  394.23    2.97  50.0
# 204   5.1180      4  224.0     14.7  390.55    2.88  50.0

# %%
data2.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# 원하는 문자열을 포함한 데이터를 찾고 싶을 때
# .str.contains("찾을 문자열")
data2[data2['Name'].str.contains("Miss")]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 2              3         1       3                    Heikkinen, Miss. Laina
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 11            12         1       1                  Bonnell, Miss. Elizabeth
# 14            15         0       3      Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# ..           ...       ...     ...                                       ...
# 866          867         1       2              Duran y More, Miss. Asuncion
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data2[data2['Sex'] != "male"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data2.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
# data2에서 Name에 Joseph이 있거나, Pclass가 2거나 3인 사람의 
# Pclass와 Name, Sex를 조회하시오.
data2.loc[(data2['Name'].str.contains("Joseph")) & ((data2['Pclass'] == 2) | (data2['Pclass'] == 1)), ['Pclass', 'Name', 'Sex']]
# Out:
#      Pclass                                               Name     Sex
# 20        2                               Fynney, Mr. Joseph J    male
# 34        1                            Meyer, Mr. Edgar Joseph    male
# 145       2                       Nicholls, Mr. Joseph Charles    male
# 194       1          Brown, Mrs. James Joseph (Margaret Tobin)  female
# 375       1              Meyer, Mrs. Edgar Joseph (Leila Saks)  female
# 608       2  Laroche, Mrs. Joseph (Juliette Marie Louise La...  female
# 685       2             Laroche, Mr. Joseph Philippe Lemercier    male

# %%
# .isin([조건1, 조건2])을 사용해서 or조건 간단하게 줄이기
data2.loc[(data2["Name"].str.contains("Joseph")) & (data2['Pclass'].isin([1,2])), ['Pclass', 'Name', 'Sex']]
# Out:
#      Pclass                                               Name     Sex
# 20        2                               Fynney, Mr. Joseph J    male
# 34        1                            Meyer, Mr. Edgar Joseph    male
# 145       2                       Nicholls, Mr. Joseph Charles    male
# 194       1          Brown, Mrs. James Joseph (Margaret Tobin)  female
# 375       1              Meyer, Mrs. Edgar Joseph (Leila Saks)  female
# 608       2  Laroche, Mrs. Joseph (Juliette Marie Louise La...  female
# 685       2             Laroche, Mr. Joseph Philippe Lemercier    male

# %% [markdown]
# ### 인덱싱/슬라이싱을 사용해서 원하는 행과 컬럼만 가져오기
# ### 데이터프레임.iloc[행시작:행 끝, 열시작:열 끝]

# %%
data2.loc[0:5, ["Pclass", "Name", "Sex"]]
# Out:
#    Pclass                                               Name     Sex
# 0       3                            Braund, Mr. Owen Harris    male
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2       3                             Heikkinen, Miss. Laina  female
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       3                           Allen, Mr. William Henry    male
# 5       3                                   Moran, Mr. James    male

# %%
data2.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
data2.iloc[4:10, 3:7]
# Out:
#                                                 Name     Sex   Age  SibSp
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1

# %%
data2.iloc[5:6, 5:6] = 30

# %%
data2.iloc[5:6, 5:6]
# Out:
#     Age
# 5  30.0

# %%
data2.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# # 현재 있는 컬럼을 활용해서 새 컬럼 추가하기

# %%
data2.loc[data2['Pclass'] == 3]['Fare'].mean()
# Out:
# 13.675550101832993

# %%
data2.loc[(data2['Pclass'] == 3) & (data2['Fare'] > 13.67)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 858          859         1       3
# 860          861         0       3
# 863          864         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 16                                Rice, Master. Eugene    male   2.0      4
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 형제자매 SibSp + 부모자식 Parch = 가족 Family
data2['Family'] = (data2['SibSp'] + data2['Parch']) + 1

# %%
data2.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Family
# 0      0  A/5 21171   7.2500   NaN        S       2
# 1      0   PC 17599  71.2833   C85        C       2

# %%
# 가족 수로 Fare를 나눠서 수정 가격 컬럼 만들기
data2['adj_fare'] = data2['Fare'] / data2['Family']

# %%
data2.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family  adj_fare
# 0      0         A/5 21171   7.2500   NaN        S       2   3.62500
# 1      0          PC 17599  71.2833   C85        C       2  35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S       1   7.92500

# %% [markdown]
# # 컬럼 이름 바꾸기
# * .rename(colums={"이전이름" : "새이름","이전이름2" : "새이름2"} => 바꾸고 싶은 컬럼 이름만 변경 가능
# * 데이터프레임.columns = [전체 새 컬럼이름]

# %%
data2.rename(columns={"PassengerId":"승객ID", "Survived" : "생존여부"})
# Out:
#      승객ID  생존여부  Pclass                                               Name  \
# 0       1     0       3                            Braund, Mr. Owen Harris
# 1       2     1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1       3                             Heikkinen, Miss. Laina
# 3       4     1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0       3                           Allen, Mr. William Henry
# ..    ...   ...     ...                                                ...
# 886   887     0       2                              Montvila, Rev. Juozas
# 887   888     1       1                       Graham, Miss. Margaret Edith
# 888   889     0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1       1                              Behr, Mr. Karl Howell
# 890   891     0       3                                Dooley, Mr. Patrick
#
# ...

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                             Braund,  Mr. Owen Harris    male  22.0      1
# 1    Cumings,  Mrs. John Bradley (Florence Briggs T...  female  38.0      1
# 2                              Heikkinen,  Miss. Laina  female  26.0      0
# 3        Futrelle,  Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen,  Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 데이터 프레임 연산함수
# * mean() : 평균
# * median() : 중앙값
# * describe() : 기초통계량, min, max, 4분위 수
# * agg() : 여러 통계량을 동시에

# %%
# Age 컬럼의 평균
data2['Age'].mean()
# Out:
# 29.69953846153846

# %%
# Age 컬럼의 중앙값
data2['Age'].median()
# Out:
# 28.0

# %%
# Age 컬럼의 중앙값
data2[['Age','Fare']].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
# 기초 통계량 보기 describe()
data2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  715.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699538    0.523008
# std     257.353842    0.486592    0.836071   14.516326    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.250000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare      Family    adj_fare
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    1.904602   19.916375
# std      0.806057   49.693429    1.613459   35.841257
# min      0.000000    0.000000    1.000000    0.000000
# 25%      0.000000    7.910400    1.000000    7.250000
# ...

# %%
# agg()
data2.agg({"Age": ["min", "max", "median", "skew"], "Fare": ["min", "max", "median", "skew"]})
# Out:
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# skew     0.389291    4.787317

# %%
# agg()
data2.agg({"Age": ["min", "max", "median", "skew"], "Fare": ["min", "max", "median", "mean"]})
# Out:
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# skew     0.389291         NaN
# mean          NaN   32.204208

# %% [markdown]
# # 그룹 집합 연산 groupby

# %%
data2[["Sex", "Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.725044

# %%
data2.groupby("Sex").mean()
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_8580\2358402445.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data2.groupby("Sex").mean()
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.725044  0.429809  0.235702
#
#              Fare    Family   adj_fare
# Sex
# female  44.479818  2.343949  25.507493
# male    25.523893  1.665511  16.873722

# %%
# 금액에 따른 성별, pclass
temp1 = data2.groupby(["Sex", "Pclass"])["Fare"].mean()

# %%
print(type(temp1))
# Out:
# <class 'pandas.core.series.Series'>

# %%
temp2 = data2.groupby(["Sex", "Pclass"])[["Fare"]].mean()

# %%
print(type(temp2))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
temp1
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
temp2.index
# Out:
# MultiIndex([('female', 1),
#             ('female', 2),
#             ('female', 3),
#             (  'male', 1),
#             (  'male', 2),
#             (  'male', 3)],
#            names=['Sex', 'Pclass'])

# %%
temp2.shape
# Out:
# (6, 1)

# %%
temp2.loc[('female', 1), "Fare"]
# Out:
# 106.12579787234043

# %%
temp2.iloc[0:1, 0:1]
# Out:
#                      Fare
# Sex    Pclass
# female 1       106.125798

# %% [markdown]
# ## 열 내부에 있는 유일 항목 갯수, 유일값 계산
# ### 범주형 데이터 일 때, 각 범주별 데이터의 빈도를 셀 때 사용
# * .unique() : 유일값을 갖는 데이터를 추출
# * .nunique(): 유일값이 몇 개인지 세어줌
# * .value_counts(): 유일값의 빈도를 계산

# %%
data2.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Family  adj_fare
# 0      0  A/5 21171   7.2500   NaN        S       2   3.62500
# 1      0   PC 17599  71.2833   C85        C       2  35.64165

# %%
data2['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data2['Pclass'].nunique()
# Out:
# 3

# %%
data2['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data2['Age'].nunique()
# Out:
# 88

# %%
data2['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data2['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# # 데이터 프레임 합치기
# * concat
# * merge
# * join

# %%
data3 = data2.iloc[400:, :]
data3
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 400          401         1       3                        Niskanen, Mr. Juha
# 401          402         0       3                           Adams, Mr. John
# 402          403         0       3                  Jussila, Miss. Mari Aina
# 403          404         0       3            Hakkarainen, Mr. Pekka Pietari
# 404          405         0       3                   Oreskovic, Miss. Marija
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# data2 데이터 프레임에 data3 데이터 프레임을 합침 axis=0
data4 = pd.concat([data2, data3])

# %%
data4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          715 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Family       891 non-null    int64
#  13  adj_fare     891 non-null    float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 97.6+ KB

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 400 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  491 non-null    int64
#  1   Survived     491 non-null    int64
#  2   Pclass       491 non-null    int64
#  3   Name         491 non-null    object
#  4   Sex          491 non-null    object
#  5   Age          392 non-null    float64
#  6   SibSp        491 non-null    int64
#  7   Parch        491 non-null    int64
#  8   Ticket       491 non-null    object
#  9   Fare         491 non-null    float64
#  10  Cabin        113 non-null    object
#  11  Embarked     490 non-null    object
#  12  Family       491 non-null    int64
#  13  adj_fare     491 non-null    float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 53.8+ KB

# %%
data5 = pd.concat([data3, data2], axis=1)
data5
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 400        401.0       1.0     3.0              Niskanen, Mr. Juha    male
# 401        402.0       0.0     3.0                 Adams, Mr. John    male
# 402        403.0       0.0     3.0        Jussila, Miss. Mari Aina  female
# 403        404.0       0.0     3.0  Hakkarainen, Mr. Pekka Pietari    male
# 404        405.0       0.0     3.0         Oreskovic, Miss. Marija  female
# ..           ...       ...     ...                             ...     ...
# 395          NaN       NaN     NaN                             NaN     NaN
# 396          NaN       NaN     NaN                             NaN     NaN
# 397          NaN       NaN     NaN                             NaN     NaN
# 398          NaN       NaN     NaN                             NaN     NaN
# 399          NaN       NaN     NaN                             NaN     NaN
#
# ...

# %% [markdown]
# ## merge
# * pd.merge(기준데이터프레임, 합칠데이터프레임, how="join 방법(left, right, inner, outer)", on="기준컬럼")

# %%
pd.merge(data2,data3, how="left", on="PassengerId")
# Out:
#      PassengerId  Survived_x  Pclass_x  \
# 0              1           0         3
# 1              2           1         1
# 2              3           1         3
# 3              4           1         1
# 4              5           0         3
# ..           ...         ...       ...
# 886          887           0         2
# 887          888           1         1
# 888          889           0         3
# 889          890           1         1
# 890          891           0         3
#
#                                                 Name_x   Sex_x  Age_x  \
# 0                             Braund,  Mr. Owen Harris    male   22.0
# 1    Cumings,  Mrs. John Bradley (Florence Briggs T...  female   38.0
# 2                              Heikkinen,  Miss. Laina  female   26.0
# 3        Futrelle,  Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                            Allen,  Mr. William Henry    male   35.0
# ...

# %% [markdown]
# # join

# %%
data3.join(data2, how="inner", on="PassengerId")
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\hi\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\hi\AppData\Local\Temp\ipykernel_8580\409143156.py", line 1, in <module>
#     data3.join(data2, how="inner", on="PassengerId")
#   File "C:\Users\hi\anaconda3\envs\testenv\lib\site-packages\pandas\core\frame.py", line 9979, in join
#   File "C:\Users\hi\anaconda3\envs\testenv\lib\site-packages\pandas\core\frame.py", line 10018, in _join_compat
#     See Also
#   File "C:\Users\hi\anaconda3\envs\testenv\lib\site-packages\pandas\core\reshape\merge.py", line 124, in merge
#     }
#   File "C:\Users\hi\anaconda3\envs\testenv\lib\site-packages\pandas\core\reshape\merge.py", line 775, in get_result
#     copy=False,
# ...

# %% [markdown]
# # 문자형 데이터 다루기
# * .str 안에 있음

# %%
# 컬럼의 데이터를 모두 소문자로 변경
data2['Name'].str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
# ,를 기준으로 문자열을 분리해 리스트로 만들기
data2['Name'] = data2['Name'].str.split(",")

# %%
data2.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         [Braund,  Mr. Owen Harris]    male  22.0      1
# 1  [Cumings,  Mrs. John Bradley (Florence Briggs ...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Family  adj_fare
# 0      0  A/5 21171   7.2500   NaN        S       2   3.62500
# 1      0   PC 17599  71.2833   C85        C       2  35.64165

# %%
# 리스트의 자료들을 합쳐서 문자로 만들기
data2['Name'] = data2['Name'].str.join(", ")

# %%
data2.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                           Braund,  Mr. Owen Harris    male  22.0      1
# 1  Cumings,  Mrs. John Bradley (Florence Briggs T...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Family  adj_fare
# 0      0  A/5 21171   7.2500   NaN        S       2   3.62500
# 1      0   PC 17599  71.2833   C85        C       2  35.64165

# %%
# ,를 기준으로 문자열 분리해 리스트로 만들고 첫번째 자료를 가져옴
data2['Name'].str.split(",").str.get(0)
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %%
# 특정 단어/문자가 포함된 행 찾기 및 가져오기
data2["Name"].str.contains("John")
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
# 이름의 길이기 가장 긴 곳을 찾아서 인덱스 반환하기 idxmax()
data2['Name'].str.len().idxmax()
# Out:
# 307

# %%
data2['Name'].str.len().max()
# Out:
# 83

# %%
data2.iloc[307]['Name']
# Out:
# 'Penasco y Castellana,  Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %%
data2.loc[data2["Name"].str.len().idxmax(), "Name"]
# Out:
# 'Penasco y Castellana,  Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %% [markdown]
# # 특정 값을 찾아 다른 값으로 바꾸기 .replace

# %%
data2['Sex'].replace({"male": "M", "female" : "F"})
# Out:
# 0      M
# 1      F
# 2      F
# 3      F
# 4      M
#       ..
# 886    M
# 887    F
# 888    F
# 889    M
# 890    M
# Name: Sex, Length: 891, dtype: object
