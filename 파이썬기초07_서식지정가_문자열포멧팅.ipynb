# %% [markdown]
# 서식지정자나 format메서드를 사용하는 이는 문자열로만 입력해야 하는 삼환에서 같은 위치의 문자를 여러 번 바꿔야 할 때가 있기 떄문이다.

# %% [markdown]
# # 1. 서식지정자%d,%s,%fm,%길이s

# %% [markdown]
# ## 1) 문자를 입력할때 %s

# %%
print('이 수업의 이름은 %s 입니다.' % '머신러닝 빅데이터 분석')
# Out:
# 이 수업의 이름은 머신러닝 빅데이터 분석 입니다.

# %%
subject = ['국어','영어','수학','과학','파이썬','장고']

# %%
for sub_name in subject:
  print('이 수업의 이름은 %s 입니다' %sub_name)
# Out:
# 이 수업의 이름은 국어 입니다
# 이 수업의 이름은 영어 입니다
# 이 수업의 이름은 수학 입니다
# 이 수업의 이름은 과학 입니다
# 이 수업의 이름은 파이썬 입니다
# 이 수업의 이름은 장고 입니다

# %% [markdown]
# ## 2) 정수를 입력할 때 %d

# %%
print('올해는 %d년 입니다.' %2023)
# Out:
# 올해는 2023년 입니다.

# %%
year = [2021,2022,2023]
for y in year:
  print('올해는 %d년 입니다.' %2023)
# Out:
# 올해는 2023년 입니다.
# 올해는 2023년 입니다.
# 올해는 2023년 입니다.

# %% [markdown]
# ## 3) 실수를 입력할 때 %f

# %%
print('사람의 정상 체온은 약 %f 입니다.' %36.5)
# Out:
# 사람의 정상 체온은 약 36.500000 입니다.

# %% [markdown]
# %f는 기본적으로 소숫점 6자리까지 표시하므로 f앞에 .자릿수를 지정하면 지정한 자릿수 만큼만 출력

# %%
print('사람의 정상 체온은 약 %.2f 입니다.' %36.5)
# Out:
# 사람의 정상 체온은 약 36.50 입니다.

# %%
print('사람의 정상 체온은 약 %.1f 입니다.' %36.5)
# Out:
# 사람의 정상 체온은 약 36.5 입니다.

# %% [markdown]
# ## 4) 서식지정자로 문자열 정렬하기 %길이s

# %%
print('%10s' % '오른쪽 정렬')
# Out:
#     오른쪽 정렬

# %% [markdown]
# 숫자 오른쪽 정렬로 출력하기

# %%
print('가격 %10d' % 1950000)
print('가격 %10d' % 71800)
# Out:
# 가격    1950000
# 가격      71800

# %%
print('오늘의 삼성전가 주가는 %10d원 입니다.' % 71800)
# Out:
# 오늘의 삼성전가 주가는      71800원 입니다.

# %% [markdown]
# # 여러항목 동시에 넣기

# %%
print('오늘은 %d년 %d월 %d일 입니다.' % (2021, 10, 6))
# Out:
# 오늘은 2021년 10월 6일 입니다.

# %%
company = ['삼성전자','LG전자','현대차','대한항공','하나투어']
stock = [71800, 121000, 195000, 31900, 86600]

# %%
for com, sto in zip(company, stock):
  print('%s의 주가는 %d 입니다.' % (com, sto))
# Out:
# 삼성전자의 주가는 71800 입니다.
# LG전자의 주가는 121000 입니다.
# 현대차의 주가는 195000 입니다.
# 대한항공의 주가는 31900 입니다.
# 하나투어의 주가는 86600 입니다.

# %% [markdown]
# # 2. format 메서드 사용하기
# print('{인덱스}'.format(값))
# print('{인덱스0}{인덱스1}{인덱스2}'.format(값1, 값2, 값3))

# %%
print('%s의 주가는 %d 입니다.' % ('삼성전자', 71800))
print('{0}의 주가는 {1}원 입니다.'.format('삼성전자',71800))
print('{1}의 주가는 {0}원 입니다.'.format('삼성전자',71800))
# Out:
# 삼성전자의 주가는 71800 입니다.
# 삼성전자의 주가는 71800원 입니다.
# 71800의 주가는 삼성전자원 입니다.

# %% [markdown]
# # format메서드로 같은 값을 여러 개 넣기

# %%
print('{0}의 주가는{1}원 입니다. \n{0}의 상한가는 {2},\n \
      {0}의 하한가는 {3}입니다.'.format('삼성전자', 71500,50200, 93000))
# Out:
# 삼성전자의 주가는71500원 입니다.
# 삼성전자의 상한가는 50200,
#        삼성전자의 하한가는 93000입니다.

# %% [markdown]
# ## format 메서드에 변수로 값 넣기

# %%
drama = '오징어 게임'
ranking = '1'

# %%
print('넷플릭스 {}위 드라마는 {}입니다.'.format(ranking, drama))
# Out:
# 넷플릭스 1위 드라마는 오징어 게임입니다.

# %%
print(f'넷플릭스 {ranking}위 드라마는 {drama}입니다.')
# Out:
# 넷플릭스 1위 드라마는 오징어 게임입니다.

# %%
for com, sto in zip(company, stock):
  print(f'{com}의 주가는 {sto}입니다.')
# Out:
# 삼성전자의 주가는 71800입니다.
# LG전자의 주가는 121000입니다.
# 현대차의 주가는 195000입니다.
# 대한항공의 주가는 31900입니다.
# 하나투어의 주가는 86600입니다.

# %% [markdown]
# # 5. format 메서드로 문자열 정렬하기
#  * print('{인덱스:<길이}'.format(값))print('{인덱스:방향 길이}'.format(값))

# %%
#오른쪽 방향으로 공백 포함 10칸
print('{0:<10}'.format('파이썬'))
# Out:
# 파이썬

# %%
#왼쪽 방향으로 공백 포함 10칸
print('{0:>10}'.format('파이썬'))
# Out:
#        파이썬

# %% [markdown]
# ## 1) 숫자 갯수 통일하기
# print('{인덱스:채울 숫자 길이 서식지정자}'.format(값)),단,서식지정자에서 %는 빼고 적는다

# %%
print('{0:02d}'.format(2))
# Out:
# 02

# %%
# 실수로 채울 경우
print('{0:08.2f}'.format(2))
# Out:
# 00002.00

# %%
month = range(1, 13)
day = range(1, 32)

# %%
for mm in month:
  mon = '{0:02d}월'.format(mm)
  print(mon)
# Out:
# 01월
# 02월
# 03월
# 04월
# 05월
# 06월
# 07월
# 08월
# 09월
# 10월
# 11월
# 12월

# %% [markdown]
# ## 반복문과 format 메서드로 네이버 영화 매월 10일의 랭킹 url 만들기

# %%
for page_num in range(1, 11):
  print('https://search.shopping.naver.com/book/search?bookTabType=ALL&pageIndex={}&pageSize=40&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&sort=REL'.format(page_num))
# Out:
# https://search.shopping.naver.com/book/search?bookTabType=ALL&pageIndex=1&pageSize=40&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&sort=REL
# https://search.shopping.naver.com/book/search?bookTabType=ALL&pageIndex=2&pageSize=40&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&sort=REL
# https://search.shopping.naver.com/book/search?bookTabType=ALL&pageIndex=3&pageSize=40&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&sort=REL
# https://search.shopping.naver.com/book/search?bookTabType=ALL&pageIndex=4&pageSize=40&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&sort=REL
# https://search.shopping.naver.com/book/search?bookTabType=ALL&pageIndex=5&pageSize=40&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&sort=REL
# https://search.shopping.naver.com/book/search?bookTabType=ALL&pageIndex=6&pageSize=40&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&sort=REL
# https://search.shopping.naver.com/book/search?bookTabType=ALL&pageIndex=7&pageSize=40&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&sort=REL
# ...
